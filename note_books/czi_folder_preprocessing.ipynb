# %%
import os
import sys

# Get the directory of the script
script_dir = os.getcwd()

# Get the parent directory of the script
parent_dir = os.path.dirname(script_dir)

# Add the parent directory to sys.path
sys.path.append(parent_dir)

from utils.pre_processing_utils import split_norm_process_all_2D_czi_folders

# %%
data_folder = '/mnt/d/lding/FA/data/FA_ML_Annabel_20250217'
output_dir = '/mnt/d/lding/FA/processed_data/FA_ML_Annabel_20250217'
os.makedirs(output_dir,exist_ok=True)
split_norm_process_all_2D_czi_folders(data_folder, output_dir,0,100)
# Out:
# Processing folder: /mnt/d/lding/FA/data/FA_ML_Annabel_20250217/eGFP-Zyxin-488_Phalloidin-405_FHL-rb-647_paxillin-m-568/Control -> /mnt/d/lding/FA/processed_data/FA_ML_Annabel_20250217/eGFP-Zyxin-488_Phalloidin-405_FHL-rb-647_paxillin-m-568/Control
# Gathering pixel values from /mnt/d/lding/FA/data/FA_ML_Annabel_20250217/eGFP-Zyxin-488_Phalloidin-405_FHL-rb-647_paxillin-m-568/Control...
# 100%|██████████| 17/17 [00:01<00:00, 16.33it/s]
# Global percentile normalization values computed.
# Processing files from /mnt/d/lding/FA/data/FA_ML_Annabel_20250217/eGFP-Zyxin-488_Phalloidin-405_FHL-rb-647_paxillin-m-568/Control...
#   6%|▌         | 1/17 [00:00<00:06,  2.51it/s]
# Saved all channels for eGFP-Zyxin 488, Phalloidin 405, FHL2(rb) 647, paxillin(m)568_control-01.
#  12%|█▏        | 2/17 [00:00<00:05,  2.81it/s]
# Saved all channels for eGFP-Zyxin 488, Phalloidin 405, FHL2(rb) 647, paxillin(m)568_control-02.
#  18%|█▊        | 3/17 [00:01<00:04,  2.91it/s]
# ...
